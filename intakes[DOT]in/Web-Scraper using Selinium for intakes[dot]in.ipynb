# %% [markdown]
# # Web-Scraper using Selinium for intakes.in

# %% [markdown]
# ### Importing Required Packages

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import pandas as pd
import os
import re

# %% [markdown]
# ### Browser

# %%
intake_url = "https://intakes.in/product-category/baby-products/"

browser=webdriver.Firefox()

browser.get(intake_url)

# %% [markdown]
# ### Extracting Product categories

# %%
dropup = browser.find_element_by_xpath('/html/body/div[1]/main/div/div[1]/div/aside[2]/ul/li[1]/button/i')
dropup.click()

prodcat = browser.find_element_by_xpath('/html/body/div[1]/main/div/div[1]/div/aside[2]/ul')
prod_cats = prodcat.text.split('\n')
print(len(prod_cats))
# Out:
# 11

# %% [markdown]
# ### Product Category Dictionary

# %%
prod_cats_dict = {}
for n in range(1, len(prod_cats)+1):
    prod_cats_dict[n] = prod_cats[n-1]

prod_cats_dict
# Out:
# {1: 'BABY PRODUCTS',
#  2: 'BEVERAGES',
#  3: 'DAIRY & FROZEN',
#  4: 'HEALTH CARE & NUTRITION',
#  5: 'HOME CARE',
#  6: 'ORAL CARE',
#  7: 'PACKAGED FOODS',
#  8: 'PERSONAL CARE',
#  9: 'STAPLES',
#  10: 'Sugar',
#  11: 'Uncategorized'}

# %% [markdown]
# ### url_cat_part

# %%
url_cat_part = {}
for n in range(1, len(prod_cats)+1):
    url_cat_part[n] = '-'.join(prod_cats_dict[n].lower().split(' '))
url_cat_part[3] = 'dairy-frozen'
url_cat_part[4] = url_cat_part[4].replace('-&', '')

url_cat_part
# Out:
# {1: 'baby-products',
#  2: 'beverages',
#  3: 'dairy-frozen',
#  4: 'health-care-nutrition',
#  5: 'home-care',
#  6: 'oral-care',
#  7: 'packaged-foods',
#  8: 'personal-care',
#  9: 'staples',
#  10: 'sugar',
#  11: 'uncategorized'}

# %% [markdown]
# # Bot

# %% [markdown]
# (for all categories except Staples & Sugar)

# %%
# %%time
### Data Dictionary

data_dict = {}
data_dict['Product Name'] = []
data_dict['MRP'] = []
data_dict['Price'] = []
data_dict['SKU'] = []
data_dict['Sub-Category'] = []

std_url = "https://intakes.in/product-category/"

'''
n - represnts the Category Number
Under the range of 1 - 11

# range(1, 2) --> Baby Products
# range(2, 3) --> Beverages
...
...
...
# range(11, 12) --> Uncategorized
Always better to run 1 category at a time.
-----------------------------------------

i - represents page number in the url
Under the range of 1 to N+1,
where N is the total number of pages under that category'''


#Product
for n in range(1, 12):
    #Page Number
    for i in range(1, ):
        url = std_url+'/'+url_cat_part[n]+f'/page/{i}/'
        browser.get(url)
        time.sleep(2)
        #Item Number
        for q in range(1, 13):
            try:
                qv = browser.find_element_by_xpath(f'/html/body/div[1]/main/div/div[2]/div/div[2]/div[{q}]/div/div[2]/div[1]/div[4]/a')
                browser.execute_script("arguments[0].click();", qv)
                time.sleep(2)
                
                #Product Name
                prod_name = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/a/h1').text
                data_dict['Product Name'].append(prod_name)

                #MRP & Price
                try:
                    mrp = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/del/span').text
                    data_dict['MRP'].append(float(mrp[1:].replace(',', '')))

                    price = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/ins/span').text
                    data_dict['Price'].append(float(price[1:].replace(',', '')))
                except:
                    mrp = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/span').text
                    price = mrp
                    data_dict['MRP'].append(float(mrp[1:].replace(',', '')))
                    data_dict['Price'].append(float(price[1:].replace(',', '')))

                #SKU
                try:
                    sku = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span[1]/span').text
                    data_dict['SKU'].append(sku)
                except:
                    data_dict['SKU'].append('-')

                #Category & Sub-Category
                try:
                    categories = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span[2]').text
                    data_dict['Sub-Category'].append(categories.replace(', '+prod_cats_dict[n], '').replace(prod_cats_dict[n]+',', '').replace(prod_cats_dict[n], '').replace('Categories:', '').strip())
                except:
                    try:
                        categories = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span').text
                        data_dict['Sub-Category'].append(categories.replace(', '+prod_cats_dict[n], '').replace(prod_cats_dict[n]+',', '').replace(prod_cats_dict[n], '').replace('Categories:', '').strip())
                    except:
                        data_dict['Sub-Category'].append('-')
                        
                #Back to main
                webdriver.ActionChains(browser).send_keys(Keys.ESCAPE).perform()
                time.sleep(3)
            except:
                print(url,'>>>' , q)
            webdriver.ActionChains(browser).send_keys(Keys.ESCAPE).perform()
            time.sleep(3)
# Out:
# https://intakes.in/product-category//uncategorized/page/2/ >>> 6
# https://intakes.in/product-category//uncategorized/page/2/ >>> 7
# https://intakes.in/product-category//uncategorized/page/2/ >>> 8
# https://intakes.in/product-category//uncategorized/page/2/ >>> 9
# https://intakes.in/product-category//uncategorized/page/2/ >>> 10
# https://intakes.in/product-category//uncategorized/page/2/ >>> 11
# https://intakes.in/product-category//uncategorized/page/2/ >>> 12
# Wall time: 1min 42s

# %% [markdown]
# (for Staples & Sugar)

# %%
### Data Dictionary

data_dict = {}
data_dict['Product Name'] = []
data_dict['MRP'] = []
data_dict['Price'] = []
data_dict['SKU'] = []
data_dict['Sub-Category'] = []

std_url = "https://intakes.in/product-category/"

for n in range(10, 11):
    for i in range(1, 2):
        url = std_url+'/'+url_cat_part[n]+f'/page/{i}/'
        browser.get(url)
        time.sleep(3)
        for q in range(1, 13):
            try:
                qv = browser.find_element_by_xpath(f'/html/body/div[1]/main/div/div[2]/div/div[2]/div[{q}]/div/div[2]/div[1]/div[4]/a')
                browser.execute_script("arguments[0].click();", qv)
                time.sleep(3)
                try:
                    grams = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/form/table/tbody/tr/td[1]/label')
                    n_grams = len(browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/form/table/tbody/tr').text.split('\n')[1:])
                    i = 1
                    while i <= n_grams:
                        prod_name = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/a/h1').text
                        gms = browser.find_element_by_xpath(f'/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/form/table/tbody/tr/td[2]/div/div[2]/div[{i}]/span').text 
                        data_dict['Product Name'].append(prod_name+'-'+gms)

                        try:
                            mrp = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/del/span').text
                            data_dict['MRP'].append(float(mrp[1:].replace(',', '')))

                            price = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/ins/span').text
                            data_dict['Price'].append(float(price[1:].replace(',', '')))                          
                        except:
                            mrp = browser.find_element_by_xpath(f'/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/span[{i}]').text
                            price = mrp         
                            data_dict['MRP'].append(float(mrp[1:].replace(',', '')))
                            data_dict['Price'].append(float(price[1:].replace(',', '')))
                        try:
                            sku = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span[1]/span').text
                            data_dict['SKU'].append(sku)
                        except:
                            data_dict['SKU'].append('-')
                        try:
                            categories = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span[2]').text
        
                            data_dict['Sub-Category'].append(categories.replace('Categories: ', '').replace('Category: ', '').replace('STAPLES', '').replace(',', '').strip())
                        except:
                            categories = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span').text
                            data_dict['Sub-Category'].append(categories.replace('Categories: ', '').replace('Category: ', '').replace('STAPLES', '').replace(',', '').strip())
                        i += 1
                except:
                    #Product Name
                    prod_name = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/a/h1').text
                    data_dict['Product Name'].append(prod_name)
                            
                    #MRP & Price
                    try:
                        mrp = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/del/span').text
                        data_dict['MRP'].append(float(mrp[1:].replace(',', '')))

                        price = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/ins/span').text
                        data_dict['Price'].append(float(price[1:].replace(',', '')))                          
                    except:
                        mrp = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[2]/p/span').text
                        price = mrp
                        data_dict['MRP'].append(float(mrp[1:].replace(',', '')))
                        data_dict['Price'].append(float(price[1:].replace(',', '')))
        
                    #SKU
                    try:
                        sku = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span[1]/span').text
                        data_dict['SKU'].append(sku)
                    except:
                        data_dict['SKU'].append('-')

                    #Sub-Category
                    try:
                        categories = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span[2]').text
                        data_dict['Sub-Category'].append(categories.replace(', '+prod_cats_dict[n], '').replace(prod_cats_dict[n]+',', '').replace(prod_cats_dict[n], '').replace('Categories:', '').strip())
                    except:
                        try:
                            categories = browser.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/div/div[2]/div/div[3]/span').text
                            data_dict['Sub-Category'].append(categories.replace(', '+prod_cats_dict[n], '').replace(prod_cats_dict[n]+',', '').replace(prod_cats_dict[n], '').replace('Categories:', '').strip())
                        except:   
                            data_dict['Sub-Category'].append('-')
                #Back to main
                webdriver.ActionChains(browser).send_keys(Keys.ESCAPE).perform()
                time.sleep(2)
            except:
                print(url,'>>>' , q)
            webdriver.ActionChains(browser).send_keys(Keys.ESCAPE).perform()
            time.sleep(2)

# %% [markdown]
# ### Checking Counts

# %%
for i in data_dict.keys():
    print(i, len(data_dict[i]))
# Out:
# Product Name 17
# MRP 17
# Price 17
# SKU 17
# Sub-Category 17

# %% [markdown]
# ### Checking by name

# %%
for x  in range(len(data_dict['Product Name'])):
    if 'SUGAR( சர்க்கரை)INTAKES' in data_dict['Product Name'][x]:
        print(x)
        print(data_dict['Product Name'][x],
             data_dict['MRP'][x],
             data_dict['Price'][x],
             data_dict['SKU'][x],
             data_dict['Sub-Category'][x])
# Out:
# 4
# SUGAR( சர்க்கரை)INTAKES-1kg 39.0 39.0 N/A Sugar
# 5
# SUGAR( சர்க்கரை)INTAKES-500gm 20.0 20.0 N/A Sugar

# %% [markdown]
# ### DELETE Product Name
#
# There are some item which have only bname no other required details like
# - SKU Number
# - MRP
# - Price
# - Categories ans Sub-Categoriees
#
# Such items will get added to Products and the correseponding Series of the dictionaries will be added by the next item details. This results in the variation in the number of elements in the Products Name Series and the rest.
#
# We have to Delete them by identifying the index number of that item in Product Name and entering it in the below cell at index place.

# %%
del(data_dict['Product Name'][360])

# %% [markdown]
# ### MRP & Price updater
#
# In some cases there are some Items those might have more than two quantity option varying with th prices and those might get wrongly mapped. So for updating the correct prices to respective quantity we can run the below code.
#
# (We need to give the index)

# %%
data_dict['MRP'][4] = 39.
data_dict['Price'][4] = 39.
data_dict['MRP'][5] = 20.
data_dict['Price'][5] = 20.

# %% [markdown]
# ### Verify

# %%
for x in range(len(data_dict['Product Name'])):
    print(x, data_dict['Product Name'][x], 
          data_dict['MRP'][x],
          data_dict['Price'][x],
          data_dict['SKU'][x],
          data_dict['Sub-Category'][x])
# Out:
# 0 Aachi Biryani Masala 50g 45.0 30.15 8906021120272 MASALA & SPICES
# 1 Aachi Chicken Kabab/65 Masala 50g 28.0 19.6 8906021120418 MASALA & SPICES
# 2 Aachi Chicken Masala 50g 28.0 18.9 8906021120463 MASALA & SPICES
# 3 Aachi Chilli Chicken Masala 50g 25.0 19.5 8906021120517 MASALA & SPICES
# 4 Aachi Chilli Powder 50g 22.0 14.3 8906021120562 MASALA & SPICES
# 5 Aachi Compounded Asafoetida-50g 26.0 23.4 8906021120128 MASALA & SPICES
# 68 Ayyappa Ghee 500ml 336.0 295.68 8908002852042 GHEE
# 69 BAKERS Black Salt Powder-100g 22.0 21.34 8906012960337 SALT, SUGAR & JAGGERY
# 70 BAKERS Kasuri Methi-25g 27.0 23.76 8906012960160 MASALA & SPICES
# 71 BAKERS Kitchen King-100g 62.0 59.52 8906012960139 MASALA & SPICES
# 72 BASMATHI RICE(பாசுமதி அரிசி)INTAKES-500gm 70.0 70.0 N/A RICE PUFFED RICE & POHA
# 73 Bengal Gram Dal(கடலை பருப்பு) INTAKES-200gm 16.0 16.0 N/A DALS & PULSES
# 74 Bengal Gram Dal(கடலை பருப்பு) INTAKES-500gm 40.0 40.0 N/A DALS & PULSES
# 75 BENGAL GRAM(சுண்டல் கடலை)INTAKES-200gm 16.0 16.0 N/A DALS & PULSES
# 76 BENGAL GRAM(சுண்டல் கடலை)INTAKES-500gm 40.0 40.0 N/A DALS & PULSES
# 77 BIG MUSTARD( பெரிய கடுகு)INTAKES-100gm 8.0 8.0 N/A DALS & PULSES
# 78 BIG MUSTARD( பெரிய கடுகு)INTAKES-200gm 16.0 16.0 N/A DALS & PULSES
# 79 BIG SOYA(பெரிய சோயா)INTAKES-200gm 19.0 19.0 N/A DALS & PULSES
# 80 BIG SOYA(பெரிய சோயா)INTAKES-500gm 44.0 44.0 N/A DALS & PULSES
# 81 BISHOP SEED( ஓமான்)INTAKES-50gm 18.0 18.0 N/A RAW SPICES
# 82 Black Urid Dhal Splits (கருப்பு உளுந்து) INTAKES-200gm 23.0 23.0 N/A DALS & PULSES
# 83 Black Urid Dhal Splits (கருப்பு உளுந்து) INTAKES-500gm 58.0 58.0 N/A DALS & PULSES
# 84 BOIL RICE(வேகவைத்த அரிசி)-1kg 30.0 30.0 N/A RICE PUFFED RICE & POHA
# 85 BOIL RICE(வேகவைத்த அரிசி)-500gm 58.0 58.0 N/A RICE PUFFED RICE & POHA
# 86 BOILED RICE 1kg 60.0 58.0 000938 RICE, PUFFED RICE & POHA
# 87 BRIYANI LEAF (பிரியாணி லீஃப்)INTAKES-10gm 5.0 5.0 N/A DRY INGREDIENTS
# 88 BROKEN PEANUTS ROUND(உடைத்த கடலை ரவுண்டு)INTAKES-200gm 18.0 18.0 N/A DALS & PULSES
# 89 BROKEN PEANUTS ROUND(உடைத்த கடலை ரவுண்டு)INTAKES-500gm 45.0 45.0 N/A DALS & PULSES
# 90 BROKEN PEANUTS(உடைத்த கடலை )INTAKES-200gm 20.0 20.0 N/A DALS & PULSES
# 91 BROKEN PEANUTS(உடைத்த கடலை )INTAKES-500gm 50.0 50.0 N/A DALS & PULSES
# 92 CANE SUGAR(கரும்பு சர்க்கரை)INTAKES-1kg 30.0 30.0 N/A SALT SUGAR & JAGGERY
# 93 CANE SUGAR(கரும்பு சர்க்கரை)INTAKES-500gm 60.0 60.0 N/A SALT SUGAR & JAGGERY
# 94 CASTORS SEED(கொட்டைமுத்து விதை)INTAKES-50gm 6.0 6.0 N/A DALS & PULSES
# 95 Chick Peace Small (வெள்ளை சுண்டல்) INTAKES-200gm 17.0 17.0 N/A DALS & PULSES
# 96 Chick Peace Small (வெள்ளை சுண்டல்) INTAKES-500gm 34.0 34.0 N/A DALS & PULSES
# 97 CHILKA MOONG DAL(பாசி உடைத்த பயறு)INTAKES-200gm 23.0 23.0 N/A DALS & PULSES
# 98 CHILKA MOONG DAL(பாசி உடைத்த பயறு)INTAKES-500gm 70.0 70.0 N/A DALS & PULSES
# 99 Coconut 25.0 25.0 FR1001 Category: FRUITS, VEGETABLES & EGGS
# 100 CORAINDER SEEDS(கொத்தமல்லி விதைகள்)INTAKES-200gm 30.0 30.0 N/A GRAINS
# 101 CORAINDER SEEDS(கொத்தமல்லி விதைகள்)INTAKES-500gm 72.0 72.0 N/A GRAINS
# 102 CORN FLOUR(சோள மாவு)INTAKES-100gm 8.0 8.0 N/A WHOLE WHEAT & WHEAT FLOUR
# 103 CORN FLOUR(சோள மாவு)INTAKES-200gm 16.0 16.0 N/A WHOLE WHEAT & WHEAT FLOUR
# 104 CUCUMBER SEED(வெள்ளரி விதை)INTAKES-100gm 69.0 69.0 N/A GRAINS
# 105 Cumin Seed (சீரகம்) INTAKES-100gm 30.0 30.0 N/A RAW SPICES
# 106 Cumin Seed (சீரகம்) INTAKES-200gm 60.0 60.0 N/A RAW SPICES
# 107 Cumin Seed (சீரகம்) INTAKES-50gm 14.0 14.0 N/A RAW SPICES
# 108 DEEP SEED(ஆழி விதை)INTAKES-50gm 12.0 12.0 N/A GRAINS
# 109 DIAMOND SUGAR( வைர சர்க்கரை)INTAKES-100gm 7.0 7.0 N/A Sugar
# 110 DOUBLE BEANS( இரட்டை பீன்ஸ்)INTAKES-500gm 69.0 69.0 N/A DALS & PULSES
# 111 DRY GINGER(சுக்கு)INTAKES-50gm 20.0 20.0 N/A DRY INGREDIENTS
# 112 DRY ROSE PETAL(உலர் ரோஸ் பெட்டல்)INTAKES-10gm 7.0 7.0 N/A DRY FRUITS
# 113 EVEREST Red Chilli Powder-100g 50.0 47.5 8901786411009 MASALA & SPICES, PACKAGED FOODS
# 114 FENNEL (பெருஞ்சீரகம்) INTAKES-100gm 16.0 16.0 N/A GRAINS
# 115 FENNEL (பெருஞ்சீரகம்) INTAKES-50gm 32.0 32.0 N/A GRAINS
# 116 FINGER YELLOW(விரலி மஞ்சள்)INTAKES-50gm 10.0 10.0 N/A MASALA & SPICES
# 117 FLAT LENTILS(தட்டை பயறு)INTAKES-200gm 18.0 18.0 N/A DALS & PULSES
# 118 FLAT LENTILS(தட்டை பயறு)INTAKES-500gm 36.0 36.0 N/A DALS & PULSES
# 119 FORTUNE BASMATI RICE 1kg FULL GRAIN 149.0 90.89 8906007287012 RICE, PUFFED RICE & POHA
# 120 FORTUNE BIRIYANI SPECIAL BASMATI RICE 1Kg 175.0 117.25 8906007283205 RICE, PUFFED RICE & POHA
# 121 FORTUNE Kachi Ghani Pure Mustard Oil-500ml 83.0 83.0 8906007280945 COOKING OILS
# 122 Fortune Sunflower Oil 1 Lit 142.0 112.0 8906007280242 COOKING OILS
# 155 INDIGENOUS NUTS (சுதேசி கடலை)INTAKES-200gm 25.0 25.0 N/A DALS & PULSES
# 156 JEERAGA SAMBA 500g 58.0 54.0 000792 RICE, PUFFED RICE & POHA
# 157 JEERAGA SAMBA BIRIYANI RICE 1kg 112.0 108.0 000793 RICE, PUFFED RICE & POHA
# 158 JP Biriyani Masala 50g 35.0 25.9 8906768630050 MASALA & SPICES
# 159 JP Chicken Masala 50g 28.0 17.36 8906074930064 MASALA & SPICES
# 160 JP Chilly Chicken Chicken Masala 50g 30.0 18.3 8906074930002 MASALA & SPICES
# 161 JP Chilly Gobi Masala 50g 22.0 14.52 8906768606050 Category: MASALA & SPICES
# 162 JP Curry Masala 50g 28.0 19.04 8906768627050 MASALA & SPICES
# 163 JP Fish Curry Masala 50g 24.0 15.12 8906074930132 MASALA & SPICES
# 164 JP Fish Fry Masala 50g 27.0 16.74 8906074930026 MASALA & SPICES
# 165 JP Mutton Masala 50g 29.0 18.85 8906074930071 MASALA & SPICES
# 166 JP Sambar Powder 50g 23.0 16.1 8906074930088 MASALA & SPICES
# 167 KAMBU BROKEN(உடைந்த கம்பு)INTAKES-500gm 28.0 28.0 N/A GRAINS
# 168 KAMBU NADU(நட்டு கம்பு)INTAKES-500gm 32.0 32.0 N/A GRAINS
# 169 KAPOK BUDS(மராத்தி மொக்கு)INTAKES-25gm 6.0 6.0 N/A DRY INGREDIENTS
# 170 LENTILS HIM(அவரை பருப்பு) INTAKES-200gm 20.0 20.0 N/A DALS & PULSES
# 171 LENTILS HIM(அவரை பருப்பு) INTAKES-500gm 49.0 49.0 N/A DALS & PULSES
# 172 LG Compounded Asafoetida-100g 153.0 137.7 840222000118 MASALA & SPICES
# 173 LG Compounded Asafoetida-50g 79.0 76.63 840222000149 MASALA & SPICES
# 174 MAIDA( மைதா)INTAKES-1kg 22.0 22.0 N/A FLOURS & SOOJI
# 175 MAIDA( மைதா)INTAKES-500gm 44.0 44.0 N/A FLOURS & SOOJI
# 176 MAIDA(மைதா)INTAKES-1kg 86.0 86.0 N/A FLOURS & SOOJI
# 177 Manila Groundnut Oil 500 ml Pet 122.0 103.7 8906014590440 COOKING OILS
# 178 MANILLA Ground nut Oil-1L 244.0 202.52 8906014590433 COOKING OILS
# 179 Mar Cold Pressed Virgin Coconut Oil 250 ml 375.0 345.0 8901088134972 COOKING OILS
# 180 Mayil Mark Wheat Broken 250g 39.0 28.0 8906016970202 FLOURS & SOOJI
# 181 Mayil Mark Wheat Broken 500g 72.0 62.0 8906016970301 FLOURS & SOOJI
# 182 MINI SOYA (மினி சோயா)INTAKES-200gm 19.0 19.0 N/A DALS & PULSES
# 183 MINI SOYA (மினி சோயா)INTAKES-500gm 44.0 44.0 N/A DALS & PULSES
# 184 Mirakle Pomace Olive Oil 500 ml 475.0 285.0 8906087222408 COOKING OILS
# 185 Moong Dal (பாசிப்பருப்பு) INTAKES-200gm 24.0 24.0 N/A DALS & PULSES
# 217 PATANJALI DALIA 500g 35.0 34.95 8904109470011 WHOLE WHEAT & WHEAT FLOUR
# 218 PEANUT FLOUR(கடலை மாவு)INTAKES-200gm 17.0 17.0 N/A FLOURS & SOOJI
# 219 PEANUT FLOUR(கடலை மாவு)INTAKES-500gm 44.0 44.0 N/A FLOURS & SOOJI
# 220 Pillsbury Chakki Fresh Atta 500g 31.0 29.45 8906000210284 Category: WHOLE WHEAT & WHEAT FLOUR
# 221 PISTA KERNALS( பிஸ்டா கர்னல்கள்)INTAKES-25gm 58.0 58.0 N/A GRAINS
# 222 POPPY SEEDS(கசகசா)INTAKES-25gm 36.0 36.0 N/A GRAINS
# 223 POPULAR APPALAM 100g 50.0 47.0 8906016500041 Category:
# 224 POPULAR APPALAM 145g 75.0 67.5 8906016500058 APPALAM.VADAGAM, SNACKS
# 225 POPULAR APPALAM 80g 48.0 43.2 8906016500072 APPALAM.VADAGAM
# 226 Porna Coconut Oil 500 ML 124.0 97.0 8906014310086 COOKING OILS
# 227 Porna Refined Rice Bran Oil 1 Lit 146.0 116.0 8906014310031 COOKING OILS
# 228  32.0 20.48 8908008846052 APPALAM.VADAGAM
# 229 PRABHATH APPALAM 150g 48.0 27.48 8908008846021 APPALAM.VADAGAM
# 230 PRABHATH APPALAM 50g 16.0 9.6 8908008846106 APPALAM.VADAGAM
# 231 PULI(புளி)INTAKES-200gm 48.0 48.0 N/A DRY INGREDIENTS
# 232 PULI(புளி)INTAKES-500gm 121.0 121.0 N/A DRY INGREDIENTS
# 233 RAGI(ராகி)INTAKES-200gm 11.0 11.0 N/A GRAINS
# 234 RAGI(ராகி)INTAKES-500gm 24.0 24.0 N/A GRAINS
# 235 RAHA GROUNP Yallini Brand Palmolein Oil-1L 113.0 87.0 8908005745167 COOKING OILS
# 236 RAS Cold Pressed Coconut Oil 200 ml Pet 75.0 64.5 8908003473161 COOKING OILS
# 237 RAS Cold Pressed Gingelly Oil 1 Lit Pet 415.0 348.6 8908003442297 COOKING OILS
# 238 RAS Cold Pressed Gingelly Oil 200 ml Pet 90.0 77.4 - COOKING OILS
# 239 RAS Cold Pressed Groundnut Oil 500 ml Pet 165.0 140.25 - COOKING OILS
# 240 RAW RICE 500g 32.0 30.0 000140 RICE, PUFFED RICE & POHA
# 241 RED AVUL KETTI(ரெட் அவுல் கெட்டி)INTAKES-200gm 11.0 11.0 N/A RICE PUFFED RICE & POHA
# 242 RED AVUL KETTI(ரெட் அவுல் கெட்டி)INTAKES-500gm 26.0 26.0 N/A RICE PUFFED RICE & POHA
# 243 RED AVUL( சிவப்பு அவுள்)INTAKES-200gm 12.0 12.0 N/A RICE PUFFED RICE & POHA
# 244 RED AVUL( சிவப்பு அவுள்)INTAKES-500gm 27.0 27.0 N/A RICE PUFFED RICE & POHA
# 245 RED KIDNEY BEAN( ராஜ்மா பீன்ஸ்)INTAKES-200gm 27.0 27.0 N/A DALS & PULSES
# 246 RED KIDNEY BEAN( ராஜ்மா பீன்ஸ்)INTAKES-500gm 67.0 67.0 N/A DALS & PULSES
# 278 SAKTHI MUTTON MASALA 50g 31.0 19.84 8906002081417 MASALA & SPICES
# 279 SAKTHI PEPPER CHICKEN MASALA 50g 40.0 25.6 8906002083152 MASALA & SPICES
# 280 SAKTHI PEPPER POWDER 50g 50.0 31.5 8906002082117 MASALA & SPICES
# 281 SAKTHI PULIYOGARE RICE POWDER 50g 26.0 18.72 8906002081011 MASALA & SPICES
# 282 SAKTHI Ragi Flour 500g 37.0 28.8 8906002082506 Category: FLOURS & SOOJI
# 283 SAKTHI RASAM POWDER 100g 70.0 42.0 8906002080625 MASALA & SPICES
# 284 SAKTHI RASAM POWDER 50g 35.0 21.7 8906002080618 MASALA & SPICES
# 285 SAKTHI SAMBAR POWDER 100g 48.0 29.76 8906002080328 MASALA & SPICES
# 286 SAKTHI SAMBAR POWDER 200g 96.0 57.6 8906002080335 MASALA & SPICES
# 287 SAKTHI SAMBAR POWDER 50g 24.0 15.36 8906002080311 MASALA & SPICES
# 288 SAKTHI TURMERIC POWDER 100g 27.0 16.2 8906002080021 Category: MASALA & SPICES
# 289 SAKTHI TURMERIC POWDER 200g 52.0 30.68 8906002080038 MASALA & SPICES
# 290 SAKTHI TURMERIC POWDER 50g 13.5 9.86 8906002080014 MASALA & SPICES
# 291 SAMAI ARUSHI(சாமை அரிசி)INTAKES-200gm 20.0 20.0 N/A RICE PUFFED RICE & POHA
# 292 SAMAI ARUSHI(சாமை அரிசி)INTAKES-500gm 41.0 41.0 N/A RICE PUFFED RICE & POHA
# 293 SATKHI CORRIANDER POWDER 100g 30.0 18.6 8906002080229 MASALA & SPICES
# 294 SEMOLINA 1Kg 49.0 48.0 000553 FLOURS & SOOJI
# 295 SEMOLINA 500kg 25.0 24.0 000101 FLOURS & SOOJI
# 296 SILVER CASTOR Oil-100ml 42.0 34.44 8906014590242 COOKING OILS
# 297 SILVER CASTOR Oil-200ml 75.0 56.25 8906014590228 COOKING OILS
# 298 SKC Ghee 50 ml 43.0 39.13 8906001590255 COOKING OILS
# 299 SKTHI VATHAL PULIKULAMBU POWDER 50g 28.0 17.08 8906002081318 MASALA & SPICES
# 300 SMALL MUSTARD( கடுகு)INTAKES-100gm 9.0 9.0 N/A GRAINS
# 301 SMALL MUSTARD( கடுகு)INTAKES-200gm 18.0 18.0 N/A GRAINS
# 302 SOLAM(சோளம்)INTAKES-200gm 13.0 13.0 N/A GRAINS
# 303 SPLIT CASSSIA(பட்டை)INTAKES-100gm 10.0 10.0 N/A DRY INGREDIENTS
# 304 SPLIT CASSSIA(பட்டை)INTAKES-25gm 19.0 19.0 N/A DRY INGREDIENTS
# 305 STARANI SEED(நட்சத்திர அனி)INTAKES-25gm 23.0 23.0 N/A DRY INGREDIENTS
# 306 Sugar Intakes Brand-1kg 39.0 39.0 int-sugar-200gm SALT SUGAR & JAGGERY
# 307 Sugar Intakes Brand-200gm 10.0 10.0 int-sugar-200gm SALT SUGAR & JAGGERY
# 308 Sugar Intakes Brand-500gm 19.5 19.5 int-sugar-200gm Category: SALT, SUGAR & JAGGERY
# 309 SUGAR( சர்க்கரை)INTAKES-1kg 39.0 39.0 N/A Sugar
# 310 SUGAR( சர்க்கரை)INTAKES-500gm 20.0 20.0 N/A Sugar
# 311 Sundrop Heart Edible Vegetable Oil 1 Lit 210.0 206.85 8901512680204 COOKING OILS
# 312 Sundrop Superlite Sunflower Oil 1 Lit 195.0 191.1 8901512102805 COOKING OILS
# 313 SWEET ANISE(ஸ்வீட் சோம்பு)INTAKES-100gm 9.0 9.0 N/A Sugar
# 314 TATA salt ROCK SALT 1Kg 120.0 106.8 8904043926612 SALT, SUGAR & JAGGERY
# 315 TATA Salt ROCK SALT 500g 65.0 60.12 8904043926605 SALT, SUGAR & JAGGERY
# 316 TATA SAMPANN WHITE POHA 500g 42.0 40.32 8904043902326 RICE, PUFFED RICE & POHA
# 317 THINAI RICE(தினை அரிசி)INTAKES-200gm 15.0 15.0 N/A RICE PUFFED RICE & POHA
# 318 THINAI RICE(தினை அரிசி)INTAKES-500gm 40.0 40.0 N/A RICE PUFFED RICE & POHA
# 319 Thumbai Gingelly Oil 1 lit Pet 316.0 278.08 8906014590402 COOKING OILS
# 320 Thumbai Gingelly Oil 500 ml Pet 158.0 139.04 8906014590419 COOKING OILS
# 321 TIMEPASS FUN STICK Tomato Twist 5.0 4.85 8901063364202 Uncategorized, PACKAGED FOODS
# 322 TIMEPASS FUN STICKS Masala Munch 5.0 4.85 8901063364219 Uncategorized, PACKAGED FOODS
# 323 TIMEPASS GROOVY CHIPS Spicy Tomato Flavour 5.0 4.85 8901063364196 Uncategorized, PACKAGED FOODS
# 324 TOOR DAL(துவரம் பருப்பு)INTAKES-1kg 123.0 123.0 N/A DALS & PULSES
# 325 TOOR DAL(துவரம் பருப்பு)INTAKES-200gm 21.0 21.0 N/A DALS & PULSES
# 326 TOOR DAL(துவரம் பருப்பு)INTAKES-500gm 65.0 65.0 N/A DALS & PULSES
# 327 Toor Dhal INTAKES-1kg 115.0 115.0 N/A DALS & PULSES
# 328 Toor Dhal INTAKES-200gm 23.0 23.0 N/A DALS & PULSES
# 329 Toor Dhal INTAKES-500gm 57.5 57.5 N/A DALS & PULSES
# 330 TT Componded Asafoetida-100g 154.0 129.36 8906000515044 Category: MASALA & SPICES
# 331 TT Componded Asafoetida-10g 20.0 17.4 8906000515051 MASALA & SPICES
# 332 TT Componded Asafoetida-15g 27.0 20.5 8906000515075 MASALA & SPICES
# 333 TT Componded Asafoetida-50g 79.0 60.83 8906000515037 MASALA & SPICES
# 334 TT Componded Asafoetida-50g 78.0 62.4 8906000515105 MASALA & SPICES
# 335 Tulsi Gingelly Oil 500 ml 142.0 113.0 8499797950500 COOKING OILS
# 336 UDHAIYAM Orid Dhall-1kg 171.0 131.67 8906002130092 DALS & PULSES
# 337 UDHAIYAM Toor Dhall-1kg 135.0 124.2 8906002131198 DALS & PULSES
# 338 Udhaya Krishna Ghee 100 ml 73.0 65.7 8908000655164 GHEE
# 339 Udhaya Krishna Ghee 200 ml 141.0 124.08 8908000655140 GHEE
# 340 Udhaya Krishna Ghee 500 ml 336.0 295.68 8908000655119 GHEE
# 341 URID DHAL(உளுந்து)INTAKES-1kg 61.0 61.0 N/A DALS & PULSES
# 342 URID DHAL(உளுந்து)INTAKES-500gm 122.0 122.0 N/A DALS & PULSES
# 343 Vada lentils(வடை பருப்பு) INTAKES-200gm 24.0 24.0 N/A DALS & PULSES
# 344 Vada lentils(வடை பருப்பு) INTAKES-500gm 57.0 57.0 N/A DALS & PULSES
# 345 VAL BEAN(அவரை பிரவுன் கடலை)INTAKES-200gm 16.0 16.0 N/A DALS & PULSES
# 346 VAL BEAN(அவரை பிரவுன் கடலை)INTAKES-500gm 40.0 40.0 N/A DALS & PULSES
# 347 VARA MILAKA(வரா மிலகா)INTAKES-100gm 18.0 18.0 N/A DRY INGREDIENTS
# 348 VARA MILAKA(வரா மிலகா)INTAKES-200gm 33.0 33.0 N/A DRY INGREDIENTS
# 349 VARA MILAKA(வரா மிலகா)INTAKES-500gm 83.0 83.0 N/A DRY INGREDIENTS
# 350 VARAKU ARUSHI(வரகு அரிசி)INTAKES-200gm 15.0 15.0 N/A RICE PUFFED RICE & POHA
# 351 VARAKU ARUSHI(வரகு அரிசி)INTAKES-500gm 40.0 40.0 N/A RICE PUFFED RICE & POHA
# 352 Vedhas Gold Filtered Groundnut Oil 1 Lit 201.0 170.85 8906010265403 COOKING OILS
# 353 WHEAT FLOUR(கோதுமை மாவு)INTAKES-1kg 25.0 25.0 N/A WHOLE WHEAT & WHEAT FLOUR
# 354 WHEAT FLOUR(கோதுமை மாவு)INTAKES-500gm 52.0 52.0 N/A WHOLE WHEAT & WHEAT FLOUR
# 355 WHEAT PUNJAB( பஞ்சாப் கோதுமை)INTAKES-1kg 34.0 34.0 N/A WHOLE WHEAT & WHEAT FLOUR
# 356 WHEAT RICE BROKEN(உடைந்த கோதுமை அரிசி)INTAKES-500gm 46.0 46.0 N/A RICE PUFFED RICE & POHA
# 357 WHEAT(கோதுமை)INTAKES-500gm 34.0 34.0 N/A WHOLE WHEAT & WHEAT FLOUR
# 358 WHITE KIDNEY BEAN(வரி பீன்)INTAKES-200gm 22.0 22.0 N/A DALS & PULSES
# 359 WHITE KIDNEY BEAN(வரி பீன்)INTAKES-500gm 59.0 59.0 N/A DALS & PULSES
# 360 WHITE SESAME SEEDS(வெள்ளை எள்)INTAKES-100gm 26.0 26.0 N/A GRAINS
# 361 WHITE SESAME SEEDS(வெள்ளை எள்)INTAKES-200gm 52.0 52.0 N/A GRAINS
# 362 WHITE TOAST(வெள்ளை சுண்டல்)INTAKES-200gm 20.0 20.0 N/A GRAINS
# 363 WHITE TOAST(வெள்ளை சுண்டல்)INTAKES-500gm 49.0 49.0 N/A GRAINS
# 364 YARA ROCK SALT COARSE 1kg 95.0 79.8 2787079070049 SALT, SUGAR & JAGGERY
# 365 YARA ROCK SALT COARSE 500g 51.0 44.88 2787079070032 SALT, SUGAR & JAGGERY
# 366 YARA ROCK SALT FINE 1kg 90.0 77.4 2787079070025 SALT, SUGAR & JAGGERY
# 367 YARA ROCK SALT FINE 500g 48.0 40.8 2787079070018 SALT, SUGAR & JAGGERY
# 368 YELLOW SOYA( யெல்லோ சோயா)INTAKES-200gm 14.0 14.0 N/A DALS & PULSES

# %% [markdown]
# #### Delete elements of Dictionary that need to be deleted.
#
# Uncomment and give proper index

# %%
#del(data_dict['Product Name'][308])
#del(data_dict['MRP'][120])
#del(data_dict['Price'][120])
#del(data_dict['SKU'][120])
#del(data_dict['Category'][120])
#del(data_dict['Sub-Category'][120])

# %% [markdown]
# ### Dictionary to DataFrame

# %%
df = pd.DataFrame(data_dict)
df.head()
# Out:
#                                     Product Name   MRP  Price            SKU  \
# 0  BRITANNIA 50-50 TIMEPASS Classic salted – 78g  10.0   9.60  8901063018280
# 1      BRITANNIA CAKE GOBBLES-55g( CHOCO CHILLS)  15.0  14.40  8901063362772
# 2        BRITANNIA CAKE ROLL YO Choco Swiss roll  10.0   9.60  8901063362956
# 3       BRITANNIA GOOD DAY Cashew Cookies – 100g  20.0  19.30  8901063093089
# 4             BRITANNIA LITTLE HEARTS Strawberry  10.0  10.00  8901063019119
# 5                    BRITANNIA MARIE GOLD – 120g  15.0  14.32  8901063162136
# 6                   BRITANNIA TIGER KREEMZ Choco   5.0   5.00  8901063164130
# 7           BRITANNIA TIGER KREEMZ Choco vanilla   5.0   5.00  8901063164185
# 8           BRITANNIA TIGER KREEMZ Elaichi – 86g  10.0  10.00  8901063164239
# 9       BRITANNIA TREAT Creme Wafers Choco – 33g  10.0   5.00  8901063032231
#
#                          Sub-Category
# 0            BISCUITS, PACKAGED FOODS
# 1  CAKE AND CUP CAKES, PACKAGED FOODS
# 2  CAKE AND CUP CAKES, PACKAGED FOODS
# 3            BISCUITS, PACKAGED FOODS
# 4        CEREAL MIXES, PACKAGED FOODS
# 5            BISCUITS, PACKAGED FOODS
# 6            BISCUITS, PACKAGED FOODS
# 7            BISCUITS, PACKAGED FOODS
# 8            BISCUITS, PACKAGED FOODS
# 9                      PACKAGED FOODS

# %% [markdown]
# ### Respective DataFrame names for each Category

# %% [raw]
# df_Baby_Products
# df_Beverages
# df_DAIRYnFROZEN
# df_Health_Care
# df_Home_Care
# df_Oral_Care
# df_Packaged_Foods
# df_Personal_Care
# df_Staples
# df_Sugar
# df_Uncategorized

# %% [markdown]
# #### Changing DataFrame to respective named df

# %%
df_Uncategorized = df

# %% [markdown]
# #### Adding Category Column and assigning value

# %%
df_Uncategorized['Category'] = 'UNCATEGORIZED'

# %%
df_Uncategorized.head()
# Out:
#                                     Product Name   MRP  Price            SKU  \
# 0  BRITANNIA 50-50 TIMEPASS Classic salted – 78g  10.0    9.6  8901063018280
# 1      BRITANNIA CAKE GOBBLES-55g( CHOCO CHILLS)  15.0   14.4  8901063362772
# 2        BRITANNIA CAKE ROLL YO Choco Swiss roll  10.0    9.6  8901063362956
# 3       BRITANNIA GOOD DAY Cashew Cookies – 100g  20.0   19.3  8901063093089
# 4             BRITANNIA LITTLE HEARTS Strawberry  10.0   10.0  8901063019119
#
#                          Sub-Category       Category
# 0            BISCUITS, PACKAGED FOODS  UNCATEGORIZED
# 1  CAKE AND CUP CAKES, PACKAGED FOODS  UNCATEGORIZED
# 2  CAKE AND CUP CAKES, PACKAGED FOODS  UNCATEGORIZED
# 3            BISCUITS, PACKAGED FOODS  UNCATEGORIZED
# 4        CEREAL MIXES, PACKAGED FOODS  UNCATEGORIZED

# %% [markdown]
# ### List of all the 11 DataFrames

# %%
[df_Baby_Products, df_Beverages, df_DAIRYnFROZEN, df_Health_Care, 
df_Home_Care, df_Oral_Care, df_Packaged_Foods, df_Personal_Care,
df_Staples, df_Sugar, df_Uncategorized]

# %% [markdown]
# ### Concatinating all dfs to one

# %%
df_Intake = pd.concat([df_Baby_Products, df_Beverages, df_DAIRYnFROZEN, df_Health_Care, 
           df_Home_Care, df_Oral_Care, df_Packaged_Foods, df_Personal_Care,
           df_Staples, df_Sugar, df_Uncategorized])

# %%
df_Intake.shape
# Out:
# (2916, 6)

# %%
df_Intake.head()
# Out:
#                                         Product Name    MRP   Price  \
# 0  Abbott Pediasure Oats and Almond Chocolate Fla...  395.0  394.90
# 1    Abbott Pediasure Premium Chocolate Flavour 200g  295.0  283.20
# 2      Abbott Pediasure Vanilla Delight Falvour 400g  545.0  510.94
# 3              Abbott Pediasure Vanilla Flavour 400g  395.0  394.90
# 4                     BABY DOVE Baby Bathing Bar 75g   52.0   50.44
#
#              SKU Sub-Category       Category
# 0  8904145912049   BABY FOODS  BABY PRODUCTS
# 1  8904145911912   BABY FOODS  BABY PRODUCTS
# 2  8904145912278   BABY FOODS  BABY PRODUCTS
# 3  8904145912025   BABY FOODS  BABY PRODUCTS
# 4  8901030764882       OTHERS  BABY PRODUCTS

# %% [markdown]
# ### Saving to Excel Sheets

# %%
writer = pd.ExcelWriter("Intakes_data.xlsx", engine='xlsxwriter')

#Intakes
df_Intake.to_excel(writer,sheet_name = 'All Categories', index=False)
#Baby Products
df_Baby_Products.to_excel(writer,sheet_name = 'BABY PRODUCTS', index=False)
#Beverages
df_Beverages.to_excel(writer,sheet_name = 'BEVERAGES', index=False)
#Dairy & Frozen
df_DAIRYnFROZEN.to_excel(writer,sheet_name = 'DAIRY & FROZEN', index=False)
#Health Care
df_Health_Care.to_excel(writer,sheet_name = 'HEALTH CARE & NUTRITION', index=False)
#Home Care
df_Home_Care.to_excel(writer,sheet_name = 'HOME CARE', index=False)
#Oral Care
df_Oral_Care.to_excel(writer,sheet_name = 'ORAL CARE', index=False)
#Packeged Foods
df_Packaged_Foods.to_excel(writer,sheet_name = 'PACKAGED FOODS', index=False)
#Personal Care
df_Personal_Care.to_excel(writer,sheet_name = 'PERSONAL CARE', index=False)
#Staples
df_Staples.to_excel(writer,sheet_name = 'STAPLES', index=False)
#Sugar
df_Sugar.to_excel(writer,sheet_name = 'SUGAR', index=False)
#Uncategorized
df_Uncategorized.to_excel(writer,sheet_name = 'UNCATEGORIZED', index=False)

writer.save()
